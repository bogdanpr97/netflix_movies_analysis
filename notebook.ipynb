# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# We will analyze data for a production company that specializes in nostalgic styles. We want to do some research on movies released in the 1990's. So we'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# We have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions.
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv", index_col=0)
netflix_df.head()
# Out:
#             type  ...             genre
# show_id           ...
# s2         Movie  ...            Dramas
# s3         Movie  ...     Horror Movies
# s4         Movie  ...            Action
# s5         Movie  ...            Dramas
# s6       TV Show  ...  International TV
#
# [5 rows x 10 columns]

# %% [markdown]
# Find out what was the most frequent movie duration in the 1990s

# %%
# Select movies that were release in the 90s
movies = netflix_df[netflix_df["type"] == "Movie"]
movies_in_90s = movies[np.logical_and(movies["release_year"] >= 1990, movies["release_year"] < 2000)]
movies_in_90s.head(10)
# Out:
#           type  ...     genre
# show_id         ...
# s8       Movie  ...    Dramas
# s167     Movie  ...    Dramas
# s211     Movie  ...  Comedies
# s239     Movie  ...  Comedies
# s274     Movie  ...    Dramas
# s344     Movie  ...    Dramas
# s456     Movie  ...    Dramas
# s467     Movie  ...    Dramas
# s487     Movie  ...  Children
# s488     Movie  ...  Children
#
# [10 rows x 10 columns]

# %% [markdown]
# Visualize the data to view the distribution of duations for movies.

# %%
# Movie duration visualisation
plt.hist(movies_in_90s["duration"])
plt.title("Movie Duration Hist")
plt.xlabel("Duration in minutes")
plt.ylabel("Count")
plt.show()

# %%
# Find the most frequent duration
durations_series = movies_in_90s["duration"].value_counts()
duration = durations_series.index[0]
print("Most frequent duration is: " + str(duration))
# Out:
# Most frequent duration is: 94

# %% [markdown]
# Find the number of short action movies release in the 1990s.

# %%
short_action_movies = movies_in_90s[np.logical_and(movies_in_90s["duration"] < 90, movies_in_90s["genre"] == "Action")]

short_movie_count = len(short_action_movies)
print("Number of short action movies: " + str(short_movie_count))
# Out:
# Number of short action movies: 7
